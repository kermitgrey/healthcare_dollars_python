# %%
# load functions that create the visualizations used in 
# the presentation below.

from visualCode import *

# %% [markdown]
# <h3>Financial Relationships in Health Care</h3>
#
# <p> Early in the 2000’s, the United States Congress became increasingly concerned about the rise in the financial relationships between pharmaceutical companies and physicians and its possible adverse impact on patient care.  As a consequence, Congress passed the Physician Payments Sunshine Act in 2010 to promote the transparency of any financial relationships between health care providers and pharmaceutical companies.  The act gave the Centers for Medicare and Medicaid Services (CMS) statutory responsibility for collecting and tracking any transfers-of-value between companies and physicians.</p>
#
# <p> CMS has developed a collection and tracking system called the Open Payments System to carry out its statutory responsibility.  Within that system, companies submit their payment transactions using a set of reporting attributes that serve to describe any transfers-of-value made to physicians.  The three major categories of data collected in Open Payments are:</p>
#
# <ul>
#     <li>General Payments: payments not connected to a research agreement.</li>
#     <li>Research Payments: payments made in connection with a research agreement.</li>
#     <li>Physician Ownership Information: ownership/investment interests physicians or their immediate family have in a reporting company.</li>
# </ul>
#
# <p> The presentation below is a descriptive analysis of the General Payments data
#     only and covers the years 2016-2019.  Moreover, it restricts itself to payments
#     pertaining only to physicians residing in the United States (the 50 states,
#     District of Columbia, and Puerto Rico).</p>

# %% [markdown]
# <h4> Open Payments Summary</h4>
#
# <p>The charts below provide a summary of the data flowing through
#     the Open Payments system, including total payments, physician
#     counts, and company counts.</p>
#
# <p> Total dollars are relatively stable across the years and show a
#     slow rise over the periods.  The cumulative total for the
#     period is \$8.8B.</p>
#
# <p> The number of participating physicians is also relatively stable,
#     although a drop is present in 2019 eventhough total payments
#     for the year increased.</p>
#
# <p> The number of companies reporting payments also display stability with
#     only 2018 showing a transient upward count.</p>

# %%
createSummaryBar();

# %% [markdown]
# <h4> Physician Counts by Total Receipts</h4>
#
# <p> It is instructive to break out the physician counts based
#     on their total receipts by year.</p>
#
# <p> For the presentation below, I have used pandas' cut function
#     to bin total physician receipts.  The first row of charts
#     displays the counts as a bar with the numeric values provided in the
#     table insert.  The second row presents the total dollar values
#     attributable to each bin.</p>
#
# <p> The summary above shows over 600K physicians annually receiving payment.
#     According to the bin count, over 81 percent, on average, receive less
#     than \$1,000 while another 15 percent receive between \$1K-10K. The remaining
#     4 percent receive above \$10K per year.</p>
#
# <p> The second row of charts shows total dollars attributable to each bin.  I have
#     reconfigured the bins to focus on the remaining 4 percent noted above.  As this
#     shows, when viewed from total dollars received, the remaining 4 percent of
#     physicians receive the vast majority of company spending.</p>

# %%
createDoctorCounts()
createDoctorDollars();

# %% [markdown]
# <h4> Top Doctors by Receipts</h4>
#
# <p> As provided above, there are physicians that are receiving very large sums.
#     The following chart serves to break out the largest recipients by amount
#     and presents them in ascending order.</p>
#
# <p> This shows a small number of doctors receiving very large dollar values
#     over the four year period.  However, those dollars are not necessarily
#     received equally every year.  Another characteristic is that total
#     receipts drop quickly as you move away from the largest recipients.</p>

# %%
createDoctorBar(topN=20);

# %% [markdown]
# <h4> Receipts by Specialty</h4>
#
# <p> All physicians belong to a specialty of medicine.  So, it
#     would be interesting to see if one specialty outranks
#     another in terms of dollar values received by physicians in
#     those specialties.  The chart below breaks out the totals by specialty and presents
#     it in ascending order.  </p>
#
# <p> As shown, Internal Medicine, Orhtopaedic
#     Surgery, and Psychiatry & Neurology are the three specialties attracting
#     the most compensation.  In all, the top ten specialties account for
#     over 82% of total receipts, out of 50 specialties in total.</p>

# %%
createSpecialtyBar(topN=10);

# %% [markdown]
# <h4> Payments by Category</h4>
#
# <p> The Open Payments System captures additional details about payments
#     made to physicians by assigning a label to each payment that
#     serves to explain the nature of that payment, herein called
#     a category.</p>
#
# <p> The chart below breaks out the payments by category across all years.</p>
#
# <p> The top three payment categories are Services, Royalty, and Consulting,
#     representing 69 percent of total.  Those are followed closely by Food/Bev
#     and Travel/Lodge.</p>

# %%
createCategoryBar();

# %% [markdown]
# <h4> Company Counts by Total Spend</h4>
#
# <p> The other major participant in Open Payments is the company making
#     a payment to a physician.  As the summary at the outset shows,
#     there are approximately 1,500 participating companies every year. The
#     following charts segment those payments by total company spend.</p>
#
# <p> For the presentation below, I used pandas' cut function to bin total
#     company payments.  The first row of charts shows the counts per bin
#     represented by the bars with the numerical values shown in a table
#     insert.  The second row shows total dollars by bin.</p>
#
# <p> If you look at the counts, on average, over 50 percent of companies spend less
#     than \$100K per year while another 34 percent spend less than \$1M.  The remaining
#     16 percent of companies spend upwards of \$1M.</p>
#
# <p> The second row of charts shows the dollar values attributable to each bin.
#     I have grouped them differently to focus on the large difference between the
#     first two bins and the remaining 16 percent of companies noted above.  This
#     reconfiguration readily shows those 16 percent (246 companies on average)
#     account for a vast majority of overall spending.</p>

# %%
createPayorCounts()
createPayorDollars();

# %% [markdown]
# <h4> Payments by Company</h4>
#
#
#
# <p> The following chart shows the top 20 companies sorted in ascending
#     order.</p>
#
# <p> An interesting characteristic that stands out is the relative consistency
#     in yearly company spend across the periods.</p>

# %%
createPayorBar(topN=20);

# %% [markdown]
# <h4> Conclusion</h4>
#
# <p> The Open Payments System shows the large volume of activity comprising
#     the financial flows between companies and physicians. However, as
#     demonstrated above, the greatest proportion of that flow is concentrated
#     in a relatively small number of participants.</p>
#
# <p> When you segment physicians by total receipts, you discern that 81 percent
#     of those physicians receive less than \$1,000 per year and another
#     15 percent receive between \$1,000 and \$10,000.  Only a small proportion
#     of the physicians fall into the highly compensated segment.  Another
#     characteristic of the population of physicians is that the largest
#     proportion of compensation is directed to physicians belonging to three
#     specialties, Internal Medicine, Orhtopaedic Surgery, and Psychiatry & Neurology. </p>
#
# <p> From the company perspective, the distribution of spending is also skewed.
#     As you saw, around 84 percent of the companies spend less than \$1M per year while
#     the vast minority spend an amount in excess of \$1M.  But, it is this minority
#     that comprises the vast majority of total spending.  Moreover, 69 percent of
#     that spending is directed in three areas, Consulting, Services, and Royalty.</p>
#
# <p> The general conclusion you can make is that companies are not spreading their
#     dollars evenly throughout the health care market. Instead, they concentrate their
#     dollars in select markets and direct there largest dollar amounts to a small
#     subset of the physician population.  And, what they are purchasing is a
#     direct service in the case of Consulting and Services or a form of
#     intellectual property via Royalty.</p>
